# %% [markdown]
# Appliances Energy Prediction - Regression
#  Description
# Dataset contains the house temperature and humidity conditions in different rooms.
#  Objective
# Predict energy consumption in watts

# %% [markdown]
# **Project presentation:**
#  https://www.canva.com/design/DAGygcPoCTY/W6Do7-DR2Kz-0U3lkQO9wg/view?utm_content=DAGygcPoCTY&utm_campaign=designshare&utm_medium=link2&utm_source=uniquelinks&utlId=h86677f36a3

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4ea53b5e-4824-4507-8def-c74e303bdf92" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ea53b5e-4824-4507-8def-c74e303bdf92">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # DATA PREPROCESSING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('Appliances Energy Prediction.csv')

# %%
data
# Out:
#                    date  Appliances  lights         T1       RH_1         T2  \
# 0      11-01-2016 17:00          60      30  19.890000  47.596667  19.200000
# 1      11-01-2016 17:10          60      30  19.890000  46.693333  19.200000
# 2      11-01-2016 17:20          50      30  19.890000  46.300000  19.200000
# 3      11-01-2016 17:30          50      40  19.890000  46.066667  19.200000
# 4      11-01-2016 17:40          60      40  19.890000  46.333333  19.200000
# ...                 ...         ...     ...        ...        ...        ...
# 19730  27-05-2016 17:20         100       0  25.566667  46.560000  25.890000
# 19731  27-05-2016 17:30          90       0  25.500000  46.500000  25.754000
# 19732  27-05-2016 17:40         270      10  25.500000  46.596667  25.628571
# 19733  27-05-2016 17:50         420      10  25.500000  46.990000  25.414000
# 19734  27-05-2016 18:00         430      10  25.500000  46.600000  25.264286
#
# ...

# %%
data.shape
# Out:
# (19735, 29)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (19735, 29)

# %%
data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
data.rename(columns={'T1': 'temp kitc C'}, inplace=True)
data.rename(columns={'RH_1': 'humd kitc %'}, inplace=True)
data.rename(columns={'T2': 'temp livroom C'}, inplace=True)
data.rename(columns={'RH_2': 'humd livroom'}, inplace=True)
data.rename(columns={'T3': 'temp laundary C'}, inplace=True)
data.rename(columns={'RH_3': 'humd laundary %'}, inplace=True)
data.rename(columns={'T4': 'temp office C'}, inplace=True)
data.rename(columns={'RH_4': 'humd office %'}, inplace=True)
data.rename(columns={'T5': 'temp bath C'}, inplace=True)
data.rename(columns={'RH_5': 'humd bath %'}, inplace=True)
data.rename(columns={'T6': 'temp outside North C'}, inplace=True)
data.rename(columns={'RH_6': 'humd outside North %'}, inplace=True)
data.rename(columns={'T7': 'temp iron C'}, inplace=True)
data.rename(columns={'RH_7': 'humd iron %'}, inplace=True)
data.rename(columns={'T8': 'temp teenager 2 C'}, inplace=True)
data.rename(columns={'RH_8': 'humd teenager 2 %'}, inplace=True)
data.rename(columns={'T9': 'temp parents C'}, inplace=True)
data.rename(columns={'RH_9': 'humd parents %'}, inplace=True)
data.rename(columns={'T_out': 'temp outside C'}, inplace=True)
data.rename(columns={'Press_mm_hg': 'pressure mm Hg'}, inplace=True)
data.rename(columns={'RH_out': 'humd outside %'}, inplace=True)
data.rename(columns={'Windspeed': 'wind speed m/s'}, inplace=True)
data.rename(columns={'Tdewpoint': 'temp dewpoint C'}, inplace=True)

# %%
data.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'temp kitc C', 'humd kitc %',
#        'temp livroom C', 'humd livroom', 'temp laundary C', 'humd laundary %',
#        'temp office C', 'humd office %', 'temp bath C', 'humd bath %',
#        'temp outside North C', 'humd outside North %', 'temp iron C',
#        'humd iron %', 'temp teenager 2 C', 'humd teenager 2 %',
#        'temp parents C', 'humd parents %', 'temp outside C', 'pressure mm Hg',
#        'humd outside %', 'wind speed m/s', 'Visibility', 'temp dewpoint C',
#        'rv1', 'rv2'],
#       dtype='object')

# %%
from scipy.stats import zscore

# %%
numeric_data = data.select_dtypes(include='number')
z_score = numeric_data.apply(zscore)

# %%
threshold = 3
outliers = (z_score.abs() > threshold).any(axis=1)

# %%
data['Outlier'] = outliers
data = data[~outliers].reset_index(drop=True)

# %%
data
# Out:
#                    date  Appliances  lights  temp kitc C  humd kitc %  \
# 0      11-01-2016 21:30         100      20    21.356667    45.826667
# 1      11-01-2016 21:40         100      20    21.390000    45.690000
# 2      11-01-2016 21:50         100      20    21.500000    45.333333
# 3      11-01-2016 22:00         110      20    21.500000    45.126667
# 4      11-01-2016 22:10         400      20    21.533333    44.966667
# ...                 ...         ...     ...          ...          ...
# 17339  27-05-2016 17:00         110       0    25.600000    47.193333
# 17340  27-05-2016 17:10          90       0    25.533333    46.860000
# 17341  27-05-2016 17:20         100       0    25.566667    46.560000
# 17342  27-05-2016 17:30          90       0    25.500000    46.500000
# 17343  27-05-2016 17:40         270      10    25.500000    46.596667
#
#        temp livroom C  humd livroom  temp laundary C  humd laundary %  \
# ...

# %%
data.shape
# Out:
# (17344, 30)

# %%
data = data.drop(['Outlier'], axis=1)

# %%
data
# Out:
#                    date  Appliances  lights  temp kitc C  humd kitc %  \
# 0      11-01-2016 21:30         100      20    21.356667    45.826667
# 1      11-01-2016 21:40         100      20    21.390000    45.690000
# 2      11-01-2016 21:50         100      20    21.500000    45.333333
# 3      11-01-2016 22:00         110      20    21.500000    45.126667
# 4      11-01-2016 22:10         400      20    21.533333    44.966667
# ...                 ...         ...     ...          ...          ...
# 17339  27-05-2016 17:00         110       0    25.600000    47.193333
# 17340  27-05-2016 17:10          90       0    25.533333    46.860000
# 17341  27-05-2016 17:20         100       0    25.566667    46.560000
# 17342  27-05-2016 17:30          90       0    25.500000    46.500000
# 17343  27-05-2016 17:40         270      10    25.500000    46.596667
#
#        temp livroom C  humd livroom  temp laundary C  humd laundary %  \
# ...

# %%
data.shape
# Out:
# (17344, 29)

# %% [markdown]
# # **EDA(Exploratory Data Analysis)**

# %%
data.boxplot(figsize=(10,10))

# %%
num_columns = data.shape[1]
num_rows = (num_columns + 1) // 2  # Calculate the number of rows for subplots

fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(12, num_rows * 4))  # Adjust figsize based on num_rows

# Flatten axes if multiple rows are used
axes = axes.flatten()

for i, column in enumerate(data.columns):
    data[column].hist(ax=axes[i], bins=20)  # Adjust bins as needed
    axes[i].set_title(f"{column}")
    axes[i].set_xlabel(column)
    axes[i].set_ylabel("Frequency")

# If there's an odd number of columns, remove the empty subplot
if num_columns % 2 != 0:
    fig.delaxes(axes[-1])

plt.tight_layout()  # Adjust layout for spacing between subplots
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3983474945.py in <cell line: 0>()
#      17     fig.delaxes(axes[-1])
#      18
# ---> 19 plt.tight_layout()  # Adjust layout for spacing between subplots
#      20 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    2833     rect: tuple[float, float, float, float] | None = None,
#    2834 ) -> None:
# -> 2835     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2836
#    2837
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in tight_layout(self, pad, h_pad, w_pad, rect)
#    3638             previous_engine = self.get_layout_engine()
#    3639             self.set_layout_engine(engine)
# -> 3640             engine.execute(self)
#    3641             if previous_engine is not None and not isinstance(
# ...

# %%
sns.pairplot(data[['Appliances', 'lights', 'rv1', 'rv2']])
plt.show()

# %%
sns.pairplot(data=data)
plt.show()

# %%
num_columns = data.shape[1]
num_rows = (num_columns + 1) // 2  # Calculate the number of rows for subplots

# Create subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(12, num_rows * 4))  # Adjust figsize based on num_rows

# Flatten axes if multiple rows are used
axes = axes.flatten()

# Loop through each column and create a count plot
for i, column in enumerate(data.columns):
    sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')  # Create count plot for each column
    axes[i].set_title(f"Count Plot for {column}")  # Set title for each subplot
    axes[i].set_xlabel(column)  # Set x-axis label
    axes[i].set_ylabel("Count")  # Set y-axis label

# If there's an odd number of columns, remove the empty subplot
if num_columns % 2 != 0:
    fig.delaxes(axes[-1])

plt.tight_layout()  # Adjust layout for spacing between subplots
plt.show()

# %%
data.loc[:, 'Average'] = data.loc[:,['temp kitc C','temp livroom C','temp laundary C','temp office C','temp bath C','temp outside North C','temp iron C','temp teenager 2 C','temp parents C','temp outside C']].mean(axis=1)

# %%
sns.barplot(x='lights', y='Average',data=data)
plt.figure(figsize=(5, 5))
plt.show()

# %%
sns.scatterplot(y='lights', x='temp kitc C', data=data)
plt.figure(figsize=(5, 5))
plt.show()

# %%
lights_counts = data['lights'].value_counts()
plt.figure(figsize=(5, 5))
plt.pie(lights_counts,labels=lights_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightcoral','red','violet','yellow'])
plt.title('Distribution of lights')
plt.show()

# %%
# Re-load the data to include the 'date' column
data = pd.read_csv('Appliances Energy Prediction (1).csv')
# Extract hour and weekday from the date column
data['date'] = pd.to_datetime(data['date'], format='%d-%m-%Y %H:%M')
data['hour'] = data['date'].dt.hour
data['weekday'] = data['date'].dt.weekday
data['month'] = data['date'].dt.month
data.drop_duplicates(inplace=True)

# Re-apply outlier removal and drop the outlier column
numeric_data = data.select_dtypes(include='number')
z_score = numeric_data.apply(zscore)
threshold = 3
outliers = (z_score.abs() > threshold).any(axis=1)
data['Outlier'] = outliers
data = data[~outliers].reset_index(drop=True)
data = data.drop(['Outlier'], axis=1)

# Re-apply column renaming after reloading data
data.rename(columns={'T1': 'temp kitc C'}, inplace=True)
data.rename(columns={'RH_1': 'humd kitc %'}, inplace=True)
data.rename(columns={'T2': 'temp livroom C'}, inplace=True)
data.rename(columns={'RH_2': 'humd livroom'}, inplace=True)
data.rename(columns={'T3': 'temp laundary C'}, inplace=True)
data.rename(columns={'RH_3': 'humd laundary %'}, inplace=True)
data.rename(columns={'T4': 'temp office C'}, inplace=True)
data.rename(columns={'RH_4': 'humd office %'}, inplace=True)
data.rename(columns={'T5': 'temp bath C'}, inplace=True)
data.rename(columns={'RH_5': 'humd bath %'}, inplace=True)
data.rename(columns={'T6': 'temp outside North C'}, inplace=True)
data.rename(columns={'RH_6': 'humd outside North %'}, inplace=True)
data.rename(columns={'T7': 'temp iron C'}, inplace=True)
data.rename(columns={'RH_7': 'humd iron %'}, inplace=True)
data.rename(columns={'T8': 'temp teenager 2 C'}, inplace=True)
data.rename(columns={'RH_8': 'humd teenager 2 %'}, inplace=True)
data.rename(columns={'T9': 'temp parents C'}, inplace=True)
data.rename(columns={'RH_9': 'humd parents %'}, inplace=True)
data.rename(columns={'T_out': 'temp outside C'}, inplace=True)
data.rename(columns={'Press_mm_hg': 'pressure mm Hg'}, inplace=True)
data.rename(columns={'RH_out': 'humd outside %'}, inplace=True)
data.rename(columns={'Windspeed': 'wind speed m/s'}, inplace=True)
data.rename(columns={'Tdewpoint': 'temp dewpoint C'}, inplace=True)

data

# %%
def daily(x,df=data):
  return df.groupby('weekday')[x].mean()
def hourly(x,df=data):
  return df.groupby('hour')[x].mean()
def monthly_daily(x,df=data):
  by_day = df.pivot_table(index='weekday',
                          columns=['month'],
                          values=x,
                          aggfunc = 'mean')
  return round(by_day,ndigits=2)

# %%
hourly('Appliances', df=data).plot(figsize=(10,9))
plt.xlabel('Hour')
plt.ylabel('Appliances consumption in Wh')
ticks = list(range(0,24,1))
plt.title('Mean Energy Consumption per Hour of a day')
plt.xticks(ticks);

# %%
daily('Appliances').plot(kind='bar', color=['pink','red','green','blue','cyan','yellow','orange'], figsize=(5,5))
ticks = list(range(0, 7, 1))
labels = 'Mon Tues Wed Thu Fri Sat Sun'.split()
plt.xlabel('Day')
plt.ylabel('Appliances consumption in Wh')
plt.title('Mean Energy Consumption per Day of week')
plt.xticks(ticks, labels);
plt.show()

# %%
sns.set(rc={'figure.figsize':(5,5)},)
ax = sns.heatmap(monthly_daily('Appliances').T,cmap='PiYG',
                 xticklabels='Mon Tues Wed Thu Fri Sat Sun'.split(),
                 yticklabels='January February March April May'.split(),
                 annot=True,fmt='g',
                 cbar_kws={'label':'Consumption in wH'}).set_title('Mean appliances consumption (wh) per weekday/month').set_fontsize('14')
plt.show()

# %%
f,axes = plt.subplots(1,2,figsize=(5,5))
sns.distplot(df_hour.appliances,hist=True,color='red',hist_kws={'edgecolor':'black'},ax=axes[0])
axes[0].set_title("Appliance's Consumption")
axes[0].set_xlabel("Appliance Wh")

sns.distplot(df_hour.log_appliances,hist=True,color='green',hist_kws={'edgecolor':'black'},ax=axes[1])
axes[1].set_title("Log Appliance's Consumption")
axes[1].set_xlabel("Appliance Log Wh")

# %%
data.corr()

# %%
plt.figure(figsize=(5,5))
heatmap = sns.heatmap(data.corr(), annot=True, cmap="coolwarm", linewidths=.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Linear regression

# %%
from sklearn.model_selection import train_test_split
x_train1, x_test1, y_train1, y_test1 = train_test_split(x, y, test_size=0.40, random_state=52)
x_train2, x_test2, y_train2, y_test2 = train_test_split(x, y, test_size=0.30, random_state=52)
x_train3, x_test3, y_train3, y_test3 = train_test_split(x, y, test_size=0.25, random_state=52)
x_train4 ,x_test4, y_train4, y_test4 = train_test_split(x, y, test_size=0.20, random_state=52)

# %%
x = data.drop(['Appliances'], axis=1)
y = data['Appliances']

# %%
x

# %%
y

# %% [markdown]
# 60-40

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x, y, test_size= .40, random_state= 52)
x_train1 = x_train1.drop('date', axis=1)
x_test1 = x_test1.drop('date', axis=1)

# %%
x_train1

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(x_train1,y_train1)

# %%
y_pred = model.predict(x_test1)

# %%
linear = pd.DataFrame({'Predicted':y_pred,'Actual':y_test1})

# %%
linear

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)

# %%
model.coef_

# %% [markdown]
# 70-30

# %%
x_train2, x_test2, y_train2, y_test2 = train_test_split(x, y, test_size= .30, random_state= 52)
x_train2 = x_train2.drop('date', axis=1)
x_test2 = x_test2.drop('date', axis=1)

# %%
model = LinearRegression()

# %%
model.fit(x_train2,y_train2)

# %%
y_pred = model.predict(x_test2)

# %%
linear = pd.DataFrame({'Predicted':y_pred,'Actual':y_test2})

# %%
linear

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test2,y_pred)

# %% [markdown]
# 75-25

# %%
x_train3, x_test3, y_train3, y_test3 = train_test_split(x, y, test_size=0.25, random_state=52)
x_train3 = x_train3.drop('date', axis=1)
x_test3 = x_test3.drop('date', axis=1)

# %%
model.fit(x_train3,y_train3)

# %%
y_pred = model.predict(x_test3)

# %%
linear = pd.DataFrame({'Predicted':y_pred,'Actual':y_test3})

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test3,y_pred)

# %% [markdown]
# 80-20

# %%
x_train4 = x_train4.drop('date', axis=1)
x_test4 = x_test4.drop('date', axis=1)
model.fit(x_train4,y_train4)

# %%
y_pred = model.predict(x_test4)

# %%
linear = pd.DataFrame({'Predicted':y_pred,'Actual':y_test4})

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test4,y_pred)

# %% [markdown]
# # Plotting the Least Squares Line

# %%
sns.pairplot(data, x_vars=['lights', 'temp kitc C', 'humd kitc %', 'temp livroom C',
       'humd livroom', 'temp laundary C', 'humd laundary %', 'temp office C',
       'humd office %', 'temp bath C', 'humd bath %', 'temp outside North C',
       'humd outside North %', 'temp iron C', 'humd iron %',
       'temp teenager 2 C', 'humd teenager 2 %', 'temp parents C',
       'humd parents %', 'temp outside C', 'pressure mm Hg', 'humd outside %',
       'wind speed m/s', 'Visibility', 'temp dewpoint C', 'rv1', 'rv2'], y_vars='Appliances', height=7, aspect=0.7, kind='reg')

# %% [markdown]
# ## KNN_Regressor

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# 60-40

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x, y, test_size= .4, random_state= 52)
x_train1 = x_train1.drop('date', axis=1)
x_test1 = x_test1.drop('date', axis=1)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model=KNeighborsRegressor(n_neighbors=5)

# %%
model.fit(x_train1, y_train1)

# %%
y_pred = model.predict(x_test1)

# %%
y_pred

# %%
knn = pd.DataFrame({'Predicted':y_pred,'Actual':y_test1})
knn

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)

# %%
plt.scatter(x_test['lights'], y_test, label='Test Data')
plt.scatter(x_test['lights'], y_pred, color='red', linewidth=1, label='KNN points')
plt.xlabel('')
plt.ylabel('Appliances')
plt.title('KNN Regression')
plt.legend()
plt.show()

# %% [markdown]
# 70-30

# %%
model.fit(x_train2, y_train2)

# %%
y_pred = model.predict(x_test2)

# %%
knn = pd.DataFrame({'Predicted':y_pred,'Actual':y_test2})

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test2,y_pred)

# %% [markdown]
# 75-25

# %%
model.fit(x_train3, y_train3)

# %%
y_pred = model.predict(x_test3)

# %%
knn = pd.DataFrame({'Predicted':y_pred,'Actual':y_test3})

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test3,y_pred)

# %% [markdown]
# 80-20

# %%
model.fit(x_train4, y_train4)

# %%
y_pred = model.predict(x_test4)

# %%
knn = pd.DataFrame({'Predicted':y_pred,'Actual':y_test4})

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test4,y_pred)

# %% [markdown]
# # **SVM_Regressor**

# %%
from sklearn.svm import SVR

# %%
model = SVR(kernel='linear')

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# 60-40

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x, y, test_size= .40, random_state= 52)
x_train1 = x_train1.drop('date', axis=1)
x_test1 = x_test1.drop('date', axis=1)

# %%
model.fit(x_train1, y_train1)

# %%
y_pred = model.predict(x_test1)

# %%
y_pred

# %%
svm = pd.DataFrame({'Predicted':y_pred,'Actual':y_test1})
svm

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)

# %%
plt.scatter(x_test['lights'], y_test, label='Test Data')
plt.scatter(x_test['lights'], y_pred, color='red', linewidth=1, label='SVM points')
plt.xlabel('lights')
plt.ylabel('Appliances')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %% [markdown]
# 70-30

# %%
model.fit(x_train2, y_train2)

# %%
y_pred = model.predict(x_test2)

# %%
svm = pd.DataFrame({'Predicted':y_pred,'Actual':y_test2})

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test2,y_pred)

# %% [markdown]
# 75-25

# %%
model.fit(x_train3, y_train3)

# %%
y_pred = model.predict(x_test3)

# %%
svm = pd.DataFrame({'Predicted':y_pred,'Actual':y_test3})

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test3,y_pred)

# %% [markdown]
# 80-20

# %%
model.fit(x_train4, y_train4)

# %%
y_pred = model.predict(x_test4)

# %%
svm = pd.DataFrame({'Predicted':y_pred,'Actual':y_test4})

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test4,y_pred)

# %% [markdown]
# # **Decision Tree**

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %% [markdown]
# 60-40

# %%
model.fit(x_train1, y_train1)

# %%
y_pred = model.predict(x_test1)

# %%
y_pred

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test1})
dt

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 10), dpi=132)
plot_tree(model, fontsize=8)
plt.show()
#plt.savefig('out.pdf')

# %% [markdown]
# 70-30

# %%
model.fit(x_train2, y_train2)

# %%
y_pred = model.predict(x_test2)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test2})

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test2,y_pred)

# %% [markdown]
# 75-35

# %%
model.fit(x_train3, y_train3)

# %%
y_pred = model.predict(x_test3)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test3})

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test3,y_pred)

# %% [markdown]
# 80-20

# %%
model.fit(x_train4, y_train4)

# %%
y_pred = model.predict(x_test4)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test4})

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test4,y_pred)

# %% [markdown]
# Decision Tree Regressor Parameter

# %%
# Create Decision Tree Regressor object
clf = DecisionTreeRegressor(criterion="absolute_error", max_depth=3) # 'absolute_error', 'poisson', 'squared_error', 'friedman_mse'

# Train Decision Tree Regressor
clf = clf.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)

# %%
r2_score(y_test,y_pred)

# %%
mean_absolute_error(y_test,y_pred)

# %%
mean_squared_error(y_test,y_pred)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse

# %%
mape = mean_absolute_percentage_error(y_test, y_pred)
print(mape)
mape = mape * 100
mape

# %%
plt.figure(figsize=(10, 6), dpi=132)
plot_tree(clf, fontsize=5)
plt.show()

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()

# %% [markdown]
# 60-40

# %%
model.fit(x_train1, y_train1)

# %%
y_pred = model.predict(x_test1)

# %%
y_pred

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test1})
dt

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)

# %% [markdown]
# 70-30

# %%
model.fit(x_train2, y_train2)

# %%
y_pred = model.predict(x_test2)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test2})

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test2,y_pred)

# %% [markdown]
# 75-25

# %%
model.fit(x_train3, y_train3)

# %%
y_pred = model.predict(x_test3)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test3})

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test3,y_pred)

# %% [markdown]
# 80-20

# %%
model.fit(x_train4, y_train4)

# %%
y_pred = model.predict(x_test4)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test4})

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test4,y_pred)

# %% [markdown]
# Random Forest Regressor Parameter

# %% [markdown]
# 60-40

# %%
# Create Random Forest Regressor object
clf = RandomForestRegressor(n_estimators=100, criterion="poisson", max_depth=15, bootstrap=True) # 'absolute_error', 'poisson', 'squared_error', 'friedman_mse'

# Train Random Forest Regressor
clf = clf.fit(x_train1,y_train1)

#Predict the response for test dataset
y_pred = clf.predict(x_test1)

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)

# %% [markdown]
# 70-30

# %%
# Create Random Forest Regressor object
clf = RandomForestRegressor(n_estimators=100, criterion="poisson", max_depth=15, bootstrap=True) # 'absolute_error', 'poisson', 'squared_error', 'friedman_mse'

# Train Random Forest Regressor
clf = clf.fit(x_train2,y_train2)

#Predict the response for test dataset
y_pred = clf.predict(x_test2)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test2,y_pred)

# %% [markdown]
# 75-25

# %%
# Create Random Forest Regressor object
clf = RandomForestRegressor(n_estimators=100, criterion="poisson", max_depth=15, bootstrap=True) # 'absolute_error', 'poisson', 'squared_error', 'friedman_mse'

# Train Random Forest Regressor
clf = clf.fit(x_train3,y_train3)

#Predict the response for test dataset
y_pred = clf.predict(x_test3)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)

# %% [markdown]
# 80-20

# %%
# Create Random Forest Regressor object
clf = RandomForestRegressor(n_estimators=100, criterion="poisson", max_depth=15, bootstrap=True) # 'absolute_error', 'poisson', 'squared_error', 'friedman_mse'

# Train Random Forest Regressor
clf = clf.fit(x_train3,y_train3)

#Predict the response for test dataset
y_pred = clf.predict(x_test3)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)

# %% [markdown]
# # **Bagging**

# %%
from sklearn.ensemble import BaggingRegressor

# %%
model = BaggingRegressor()

# %% [markdown]
# 60-40

# %%
model.fit(x_train1, y_train1)

# %%
y_pred = model.predict(x_test1)

# %%
y_pred

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test1})
dt

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)

# %% [markdown]
# 70-30

# %%
model.fit(x_train2, y_train2)

# %%
y_pred = model.predict(x_test2)
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test2})

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test2,y_pred)

# %% [markdown]
# 75-25

# %%
model.fit(x_train3, y_train3)

# %%
y_pred = model.predict(x_test3)
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test3})

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test3,y_pred)

# %% [markdown]
# 80-20

# %%
model.fit(x_train4, y_train4)

# %%
y_pred = model.predict(x_test4)
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test4})

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test4,y_pred)

# %% [markdown]
# Bagging Regressor Parameter

# %%
# Create Bagging Regressor object
from sklearn.tree import DecisionTreeRegressor
base_estimator = DecisionTreeRegressor(max_depth=18, random_state=52)
br = BaggingRegressor(estimator=base_estimator, n_estimators=100, bootstrap=True)

# Train Bagging Regressor
br = br.fit(x_train1,y_train1)

#Predict the response for test dataset
y_pred = br.predict(x_test1)

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)

# %% [markdown]
# 70-30

# %%
# Create Bagging Regressor object
from sklearn.tree import DecisionTreeRegressor
base_estimator = DecisionTreeRegressor(max_depth=18, random_state=52)
br = BaggingRegressor(estimator=base_estimator, n_estimators=100, bootstrap=True)

# Train Bagging Regressor
br = br.fit(x_train2,y_train2)

#Predict the response for test dataset
y_pred = br.predict(x_test2)

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test2,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test2,y_pred)

# %% [markdown]
# 75-25

# %%
# Create Bagging Regressor object
from sklearn.tree import DecisionTreeRegressor
base_estimator = DecisionTreeRegressor(max_depth=18, random_state=52)
br = BaggingRegressor(estimator=base_estimator, n_estimators=100, bootstrap=True)

# Train Bagging Regressor
br = br.fit(x_train3,y_train3)

#Predict the response for test dataset
y_pred = br.predict(x_test3)

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test3,y_pred)

# %% [markdown]
# 80-20

# %%
# Create Bagging Regressor object
from sklearn.tree import DecisionTreeRegressor
base_estimator = DecisionTreeRegressor(max_depth=18, random_state=52)
br = BaggingRegressor(estimator=base_estimator, n_estimators=100, bootstrap=True)

# Train Bagging Regressor
br = br.fit(x_train4,y_train4)

#Predict the response for test dataset
y_pred = br.predict(x_test4)

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test4,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test4,y_pred)

# %% [markdown]
# # **Boosting**

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
model = AdaBoostRegressor()

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# 60-40

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x, y, test_size= .4, random_state= 52)
x_train1= x_train1.drop('date', axis=1)
x_test1 = x_test1.drop('date', axis=1)

# %%
model.fit(x_train1, y_train1)
# Out:
# AdaBoostRegressor()

# %%
y_pred = model.predict(x_test1)

# %%
y_pred
# Out:
# array([ 83.10961969,  83.10961969, 141.01598934, ..., 115.30311159,
#         94.81651376,  89.19902913])

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test1})
dt
# Out:
#         Predicted  Actual
# 4838    83.109620     300
# 2194    83.109620      50
# 15175  141.015989      80
# 12629  115.303112      40
# 770    111.466809      60
# ...           ...     ...
# 5226   147.834525      60
# 11059   83.109620      50
# 16106  115.303112      80
# 4154    94.816514      50
# 15774   89.199029      60
#
# [6938 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)
# Out:
# -0.012486383827237324

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)
# Out:
# 51.519474607653144

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)
# Out:
# 0.8101618638826862

# %% [markdown]
# 70-30

# %%
x_train2= x_train2.drop('date', axis=1)
x_test2 = x_test2.drop('date', axis=1)

# %%
model.fit(x_train2, y_train2)
# Out:
# AdaBoostRegressor()

# %%
y_pred = model.predict(x_test2)
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test2})

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred)
# Out:
# -0.16256812254920372

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test2,y_pred)
# Out:
# 60.7853464176562

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test2,y_pred)
# Out:
# 0.9917867767635214

# %% [markdown]
# 75-25

# %%
x_train3= x_train3.drop('date', axis=1)
x_test3 = x_test3.drop('date', axis=1)

# %%
model.fit(x_train3, y_train3)
# Out:
# AdaBoostRegressor()

# %%
y_pred = model.predict(x_test3)
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test3})

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred)
# Out:
# 0.0004752430809410457

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)
# Out:
# 51.04905901880061

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test3,y_pred)
# Out:
# 0.7899433815060695

# %% [markdown]
# 80-20

# %%
x_train4= x_train4.drop('date', axis=1)
x_test4 = x_test4.drop('date', axis=1)

# %%
model.fit(x_train4, y_train4)
# Out:
# AdaBoostRegressor()

# %%
y_pred = model.predict(x_test4)
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test4})

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred)
# Out:
# -0.08194568797971091

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test4,y_pred)
# Out:
# 58.50730946495059

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test4,y_pred)
# Out:
# 0.9397260024079813

# %% [markdown]
# GradientBoost_Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model = GradientBoostingRegressor()

# %% [markdown]
# 60-40

# %%
model.fit(x_train1, y_train1)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = model.predict(x_test1)

# %%
y_pred
# Out:
# array([83.29594734, 50.42372881, 70.13253045, ..., 91.23100093,
#        60.90214989, 71.56739953])

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test1})
dt
# Out:
#         Predicted  Actual
# 4838    83.295947     300
# 2194    50.423729      50
# 15175   70.132530      80
# 12629   81.087214      40
# 770     82.623524      60
# ...           ...     ...
# 5226   161.081997      60
# 11059   62.780474      50
# 16106   91.231001      80
# 4154    60.902150      50
# 15774   71.567400      60
#
# [6938 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)
# Out:
# 0.2630189816722268

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)
# Out:
# 32.57809668482556

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)
# Out:
# 0.406321431277763

# %% [markdown]
# 70-30

# %%
model.fit(x_train2, y_train2)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = model.predict(x_test2)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test2})
dt
# Out:
#         Predicted  Actual
# 4838    92.524897     300
# 2194    57.896536      50
# 15175   76.040428      80
# 12629   78.638726      40
# 770     79.180080      60
# ...           ...     ...
# 1714    39.858126      50
# 4876   122.194725     140
# 9359    52.513096      50
# 5285    56.218029      40
# 15755   65.183553      30
#
# [5204 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred)
# Out:
# 0.2635291140067434

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test2,y_pred)
# Out:
# 32.65279063648571

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test2,y_pred)
# Out:
# 0.4054228840314371

# %% [markdown]
# 70-25

# %%
model.fit(x_train3, y_train3)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = model.predict(x_test3)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test3})
dt
# Out:
#         Predicted  Actual
# 4838    97.208084     300
# 2194    57.234075      50
# 15175   80.411895      80
# 12629   86.209417      40
# 770     78.612836      60
# ...           ...     ...
# 2460    66.808972      40
# 219     57.593560      30
# 1322    47.529983      40
# 8783    96.354480      60
# 12045  107.950878      90
#
# [4336 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred)
# Out:
# 0.2655404470065823

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)
# Out:
# 32.864216372580835

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test3,y_pred)
# Out:
# 0.40382000980398136

# %% [markdown]
# 80-20

# %%
model.fit(x_train4, y_train4)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = model.predict(x_test4)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test4})
dt
# Out:
#        Predicted  Actual
# 4838   93.772784     300
# 2194   56.913510      50
# 15175  65.731811      80
# 12629  84.292114      40
# 770    73.442330      60
# ...          ...     ...
# 6994   65.558814      60
# 13337  99.153262     110
# 13116  70.224036      50
# 8659   68.635965      30
# 198    93.652565     350
#
# [3469 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred)
# Out:
# 0.2712994605723953

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test4,y_pred)
# Out:
# 32.985567886317305

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test4,y_pred)
# Out:
# 0.3998488618473671

# %% [markdown]
# GradientBoosting Regressor Parameter

# %% [markdown]
# 60-40

# %%
# Create Boosting Regressor object
br = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, loss='quantile', criterion='squared_error') #'quantile', 'huber', 'absolute_error', 'squared_error'

# Train Boosting Regressor
br = br.fit(x_train1,y_train1)

#Predict the response for test dataset
y_pred = br.predict(x_test1)

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)
# Out:
# -0.24533076431888712

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)
# Out:
# 58.51550925920793

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)
# Out:
# 0.9300067540634234

# %% [markdown]
# XGBoost_Regressor

# %%
from xgboost import XGBRegressor

# %%
model = XGBRegressor()

# %% [markdown]
# 60-40

# %%
model.fit(x_train1, y_train1)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(x_test1)

# %%
y_pred
# Out:
# array([147.51836 ,  38.898422,  63.92634 , ..., 111.62296 ,  52.572784,
#         53.441433], dtype=float32)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test1})
dt
# Out:
#         Predicted  Actual
# 4838   147.518356     300
# 2194    38.898422      50
# 15175   63.926338      80
# 12629   77.707199      40
# 770     63.551647      60
# ...           ...     ...
# 5226    63.495686      60
# 11059   59.111156      50
# 16106  111.622963      80
# 4154    52.572784      50
# 15774   53.441433      60
#
# [6938 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)
# Out:
# 0.4446006417274475

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)
# Out:
# 26.55073356628418

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)
# Out:
# 0.3162202537059784

# %% [markdown]
# 70-30

# %%
model.fit(x_train2, y_train2)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(x_test2)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test2})
dt
# Out:
#         Predicted  Actual
# 4838   205.123810     300
# 2194    48.945328      50
# 15175  108.540993      80
# 12629   47.237827      40
# 770     50.216129      60
# ...           ...     ...
# 1714    47.373951      50
# 4876   109.971535     140
# 9359    51.947880      50
# 5285    49.857311      40
# 15755   45.524693      30
#
# [5204 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred)
# Out:
# 0.44725650548934937

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test2,y_pred)
# Out:
# 26.670610427856445

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test2,y_pred)
# Out:
# 0.31828245520591736

# %% [markdown]
# 75-25

# %%
model.fit(x_train3, y_train3)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(x_test3)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test3})
dt
# Out:
#         Predicted  Actual
# 4838   188.649231     300
# 2194    41.057583      50
# 15175   84.467171      80
# 12629   39.709473      40
# 770     52.268284      60
# ...           ...     ...
# 2460    81.950661      40
# 219     36.226112      30
# 1322    40.373287      40
# 8783   120.673058      60
# 12045  137.697952      90
#
# [4336 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred)
# Out:
# 0.44817501306533813

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred)
# Out:
# 26.613367080688477

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test3,y_pred)
# Out:
# 0.31621211767196655

# %% [markdown]
# 80-20

# %%
model.fit(x_train4, y_train4)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(x_test4)

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test4})
dt
# Out:
#         Predicted  Actual
# 4838   218.418579     300
# 2194    45.650089      50
# 15175   80.290009      80
# 12629   54.266747      40
# 770     64.387970      60
# ...           ...     ...
# 6994    67.908165      60
# 13337  109.797539     110
# 13116   60.451931      50
# 8659    65.853531      30
# 198     89.663437     350
#
# [3469 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred)
# Out:
# 0.464743435382843

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test4,y_pred)
# Out:
# 26.37687873840332

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test4,y_pred)
# Out:
# 0.3067678213119507

# %% [markdown]
# XGBoosting Regressor Parameter

# %%
# Create Boosting Regressor object
br = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, n_jobs=-1)

# Train Boosting Regressor
br = br.fit(x_train1,y_train1)

#Predict the response for test dataset
y_pred = br.predict(x_test1)

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred)
# Out:
# 0.3998485803604126

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred)
# Out:
# 27.752471923828125

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test1,y_pred)
# Out:
# 0.33271369338035583

# %% [markdown]
# # **Variance Inflation Factor (VIF)**

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
data
# Out:
#                    date  Appliances  lights  temp kitc C  humd kitc %  \
# 0      11-01-2016 21:30         100      20    21.356667    45.826667
# 1      11-01-2016 21:40         100      20    21.390000    45.690000
# 2      11-01-2016 21:50         100      20    21.500000    45.333333
# 3      11-01-2016 22:00         110      20    21.500000    45.126667
# 4      11-01-2016 22:10         400      20    21.533333    44.966667
# ...                 ...         ...     ...          ...          ...
# 17339  27-05-2016 17:00         110       0    25.600000    47.193333
# 17340  27-05-2016 17:10          90       0    25.533333    46.860000
# 17341  27-05-2016 17:20         100       0    25.566667    46.560000
# 17342  27-05-2016 17:30          90       0    25.500000    46.500000
# 17343  27-05-2016 17:40         270      10    25.500000    46.596667
#
#        temp livroom C  humd livroom  temp laundary C  humd laundary %  \
# ...

# %%
x = data.drop(['Appliances','humd outside North %'], axis=1)

# %%
x
# Out:
#                    date  lights  temp kitc C  humd kitc %  temp livroom C  \
# 0      11-01-2016 21:30      20    21.356667    45.826667       20.666667
# 1      11-01-2016 21:40      20    21.390000    45.690000       20.700000
# 2      11-01-2016 21:50      20    21.500000    45.333333       20.700000
# 3      11-01-2016 22:00      20    21.500000    45.126667       20.790000
# 4      11-01-2016 22:10      20    21.533333    44.966667       20.790000
# ...                 ...     ...          ...          ...             ...
# 17339  27-05-2016 17:00       0    25.600000    47.193333       25.968571
# 17340  27-05-2016 17:10       0    25.533333    46.860000       25.978000
# 17341  27-05-2016 17:20       0    25.566667    46.560000       25.890000
# 17342  27-05-2016 17:30       0    25.500000    46.500000       25.754000
# 17343  27-05-2016 17:40      10    25.500000    46.596667       25.628571
#
#        humd livroom  temp laundary C  humd laundary %  temp office C  \
# ...

# %%
data.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'temp kitc C', 'humd kitc %',
#        'temp livroom C', 'humd livroom', 'temp laundary C', 'humd laundary %',
#        'temp office C', 'humd office %', 'temp bath C', 'humd bath %',
#        'temp outside North C', 'humd outside North %', 'temp iron C',
#        'humd iron %', 'temp teenager 2 C', 'humd teenager 2 %',
#        'temp parents C', 'humd parents %', 'temp outside C', 'pressure mm Hg',
#        'humd outside %', 'wind speed m/s', 'Visibility', 'temp dewpoint C',
#        'rv1', 'rv2'],
#       dtype='object')

# %%
vif_data = pd.DataFrame()
x_numeric = x.drop('date', axis=1)
vif_data["feature"] = x_numeric.columns
vif_data["VIF"] = [variance_inflation_factor(x_numeric.values, i) for i in range(x_numeric.shape[1])]
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)

# %%
vif_data
# Out:
#                  feature          VIF
# 0                 lights     1.478212
# 1            temp kitc C  3917.292940
# 2            humd kitc %  2083.569449
# 3         temp livroom C  2794.373732
# 4           humd livroom  2437.094226
# 5        temp laundary C  1261.011409
# 6        humd laundary %  1666.247793
# 7          temp office C  1067.498780
# 8          humd office %  1451.279596
# 9            temp bath C  1299.073620
# 10           humd bath %    74.037435
# 11  temp outside North C    71.954491
# 12           temp iron C  1626.501589
# 13           humd iron %   506.265429
# 14     temp teenager 2 C  1003.547493
# 15     humd teenager 2 %   572.965269
# 16        temp parents C  2590.174903
# 17        humd parents %   637.531194
# 18        temp outside C   565.419569
# 19        pressure mm Hg  2911.001526
# 20        humd outside %  1837.698255
# 21        wind speed m/s     5.302241
# 22            Visibility    11.989133
# 23       temp dewpoint C   210.826617
# ...

# %%
x = data.drop(['Appliances','humd outside North %','temp kitc C','temp parents C','rv1'], axis=1)
x_numeric = x.drop('date', axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x_numeric.columns
vif_data["VIF"] = [variance_inflation_factor(x_numeric.values, i) for i in range(x_numeric.shape[1])]
vif_data
# Out:
#                  feature          VIF
# 0                 lights     1.427143
# 1            humd kitc %  1562.885764
# 2         temp livroom C  1539.023684
# 3           humd livroom  1897.771939
# 4        temp laundary C  1017.531430
# 5        humd laundary %  1627.541106
# 6          temp office C  1017.499914
# 7          humd office %  1447.083180
# 8            temp bath C  1130.545917
# 9            humd bath %    73.718315
# 10  temp outside North C    61.983632
# 11           temp iron C  1170.980558
# 12           humd iron %   483.842487
# 13     temp teenager 2 C   892.363912
# 14     humd teenager 2 %   569.244279
# 15        humd parents %   630.413465
# 16        temp outside C   554.886688
# 17        pressure mm Hg  2907.428993
# 18        humd outside %  1829.566404
# 19        wind speed m/s     5.237993
# 20            Visibility    11.980531
# 21       temp dewpoint C   210.017447
# 22                   rv2     3.991291

# %%
vif_data = pd.DataFrame()
x_numeric = x.select_dtypes(include=np.number) # Select only numeric columns
vif_data["feature"] = x_numeric.columns
vif_data["VIF"] = [variance_inflation_factor(x_numeric.values, i) for i in range(x_numeric.shape[1])]
vif_data
# Out:
#                  feature          VIF
# 0                 lights     1.427143
# 1            humd kitc %  1562.885764
# 2         temp livroom C  1539.023684
# 3           humd livroom  1897.771939
# 4        temp laundary C  1017.531430
# 5        humd laundary %  1627.541106
# 6          temp office C  1017.499914
# 7          humd office %  1447.083180
# 8            temp bath C  1130.545917
# 9            humd bath %    73.718315
# 10  temp outside North C    61.983632
# 11           temp iron C  1170.980558
# 12           humd iron %   483.842487
# 13     temp teenager 2 C   892.363912
# 14     humd teenager 2 %   569.244279
# 15        humd parents %   630.413465
# 16        temp outside C   554.886688
# 17        pressure mm Hg  2907.428993
# 18        humd outside %  1829.566404
# 19        wind speed m/s     5.237993
# 20            Visibility    11.980531
# 21       temp dewpoint C   210.017447
# 22                   rv2     3.991291

# %%
x = data.drop(['Appliances','humd outside North %','temp kitc C','temp parents C'], axis=1)
x_numeric = x.drop(['date', 'rv1'], axis=1) # Drop date and one of the rv columns
vif_data = pd.DataFrame()
vif_data["feature"] = x_numeric.columns
vif_data["VIF"] = [variance_inflation_factor(x_numeric.values, i) for i in range(x_numeric.shape[1])]
vif_data
# Out:
#                  feature          VIF
# 0                 lights     1.427143
# 1            humd kitc %  1562.885764
# 2         temp livroom C  1539.023684
# 3           humd livroom  1897.771939
# 4        temp laundary C  1017.531430
# 5        humd laundary %  1627.541106
# 6          temp office C  1017.499914
# 7          humd office %  1447.083180
# 8            temp bath C  1130.545917
# 9            humd bath %    73.718315
# 10  temp outside North C    61.983632
# 11           temp iron C  1170.980558
# 12           humd iron %   483.842487
# 13     temp teenager 2 C   892.363912
# 14     humd teenager 2 %   569.244279
# 15        humd parents %   630.413465
# 16        temp outside C   554.886688
# 17        pressure mm Hg  2907.428993
# 18        humd outside %  1829.566404
# 19        wind speed m/s     5.237993
# 20            Visibility    11.980531
# 21       temp dewpoint C   210.017447
# 22                   rv2     3.991291

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                  feature          VIF
# 0                 lights     1.418167
# 1            humd kitc %   854.042461
# 2         temp livroom C   551.037452
# 3        temp laundary C   953.779609
# 4        humd laundary %  1611.996588
# 5          temp office C   959.082842
# 6          humd office %  1320.030074
# 7            temp bath C  1074.473525
# 8            humd bath %    73.660033
# 9   temp outside North C    61.929638
# 10           temp iron C  1166.932734
# 11           humd iron %   476.241335
# 12     temp teenager 2 C   855.251893
# 13     humd teenager 2 %   553.821986
# 14        humd parents %   628.255151
# 15        temp outside C   219.272068
# 16        humd outside %   478.409000
# 17        wind speed m/s     5.162208
# 18            Visibility    11.963078
# ...

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1','rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','humd bath %'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                  feature         VIF
# 0                 lights    1.292281
# 1            humd kitc %  384.312180
# 2         temp livroom C  435.138526
# 3          temp office C  517.290901
# 4   temp outside North C   57.813142
# 5            humd iron %  377.893311
# 6      temp teenager 2 C  411.037340
# 7      humd teenager 2 %  440.683887
# 8         humd parents %  495.833458
# 9         temp outside C  193.647898
# 10        humd outside %  423.004813
# 11        wind speed m/s    5.079947
# 12            Visibility   11.890967
# 13       temp dewpoint C   36.690726

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1','rv2','humd laundary %'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                  feature          VIF
# 0                 lights     1.417894
# 1            humd kitc %   651.414987
# 2         temp livroom C   530.713217
# 3        temp laundary C   952.650222
# 4          temp office C   958.233817
# 5          humd office %  1225.630514
# 6            temp bath C  1063.781768
# 7            humd bath %    73.463043
# 8   temp outside North C    59.076186
# 9            temp iron C  1161.702421
# 10           humd iron %   469.899387
# 11     temp teenager 2 C   854.657442
# 12     humd teenager 2 %   547.596179
# 13        humd parents %   596.924190
# 14        temp outside C   202.534083
# 15        humd outside %   453.105871
# 16        wind speed m/s     5.160986
# 17            Visibility    11.959284
# 18       temp dewpoint C    38.815581

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1','rv2','humd laundary %','humd office %'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                  feature          VIF
# 0                 lights     1.382047
# 1            humd kitc %   401.737298
# 2         temp livroom C   467.717746
# 3        temp laundary C   947.474839
# 4          temp office C   847.421816
# 5            temp bath C  1029.643550
# 6            humd bath %    73.200164
# 7   temp outside North C    58.838213
# 8            temp iron C  1126.562802
# 9            humd iron %   428.099624
# 10     temp teenager 2 C   850.851465
# 11     humd teenager 2 %   546.352770
# 12        humd parents %   536.795750
# 13        temp outside C   194.497775
# 14        humd outside %   428.573450
# 15        wind speed m/s     5.096629
# 16            Visibility    11.942962
# 17       temp dewpoint C    37.802192

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                  feature         VIF
# 0                 lights    1.338050
# 1            humd kitc %  398.407373
# 2         temp livroom C  445.840254
# 3        temp laundary C  937.308879
# 4          temp office C  724.228139
# 5            temp bath C  966.822173
# 6            humd bath %   73.000112
# 7   temp outside North C   58.523792
# 8            humd iron %  388.752105
# 9      temp teenager 2 C  596.256240
# 10     humd teenager 2 %  451.508003
# 11        humd parents %  509.593971
# 12        temp outside C  193.874297
# 13        humd outside %  428.495404
# 14        wind speed m/s    5.088285
# 15            Visibility   11.935174
# 16       temp dewpoint C   37.093750

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                  feature         VIF
# 0                 lights    1.326317
# 1            humd kitc %  395.664763
# 2         temp livroom C  442.447164
# 3          temp office C  687.061062
# 4            temp bath C  835.604142
# 5            humd bath %   72.367654
# 6   temp outside North C   58.260822
# 7            humd iron %  385.041336
# 8      temp teenager 2 C  553.465636
# 9      humd teenager 2 %  451.318972
# 10        humd parents %  498.118595
# 11        temp outside C  193.669091
# 12        humd outside %  423.212659
# 13        wind speed m/s    5.083018
# 14            Visibility   11.893271
# 15       temp dewpoint C   37.076812

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                  feature         VIF
# 0                 lights    1.300615
# 1            humd kitc %  392.311409
# 2         temp livroom C  438.334983
# 3          temp office C  518.822748
# 4            humd bath %   72.356022
# 5   temp outside North C   58.134083
# 6            humd iron %  382.495119
# 7      temp teenager 2 C  415.432115
# 8      humd teenager 2 %  450.611891
# 9         humd parents %  497.644360
# 10        temp outside C  193.669060
# 11        humd outside %  423.180335
# 12        wind speed m/s    5.083015
# 13            Visibility   11.893266
# 14       temp dewpoint C   36.816107

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','temp office C'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                  feature         VIF
# 0                 lights    1.290976
# 1            humd kitc %  392.285010
# 2         temp livroom C  362.265183
# 3            humd bath %   72.142387
# 4   temp outside North C   57.976282
# 5            humd iron %  381.574326
# 6      temp teenager 2 C  277.365030
# 7      humd teenager 2 %  449.486399
# 8         humd parents %  497.384995
# 9         temp outside C  188.209162
# 10        humd outside %  412.571074
# 11        wind speed m/s    4.783682
# 12            Visibility   11.815021
# 13       temp dewpoint C   36.017277

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','temp office C','humd parents %'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                  feature         VIF
# 0                 lights    1.272124
# 1            humd kitc %  359.407884
# 2         temp livroom C  362.168446
# 3            humd bath %   71.889674
# 4   temp outside North C   57.837054
# 5            humd iron %  353.125181
# 6      temp teenager 2 C  277.350872
# 7      humd teenager 2 %  398.537873
# 8         temp outside C  183.184454
# 9         humd outside %  398.652175
# 10        wind speed m/s    4.725845
# 11            Visibility   11.813874
# 12       temp dewpoint C   34.139619

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','temp office C','humd parents %','humd teenager 2 %'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                  feature         VIF
# 0                 lights    1.252455
# 1            humd kitc %  349.431844
# 2         temp livroom C  361.882230
# 3            humd bath %   70.479799
# 4   temp outside North C   56.380132
# 5            humd iron %  234.622500
# 6      temp teenager 2 C  274.009333
# 7         temp outside C  176.710258
# 8         humd outside %  371.518944
# 9         wind speed m/s    4.686579
# 10            Visibility   11.747503
# 11       temp dewpoint C   33.327817

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','temp office C','humd parents %',
               'humd teenager 2 %','temp livroom C'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                  feature         VIF
# 0                 lights    1.243646
# 1            humd kitc %  347.921201
# 2            humd bath %   70.104392
# 3   temp outside North C   51.252364
# 4            humd iron %  220.167256
# 5      temp teenager 2 C  208.424060
# 6         temp outside C  171.774057
# 7         humd outside %  361.185214
# 8         wind speed m/s    4.677766
# 9             Visibility   11.746455
# 10       temp dewpoint C   28.081765

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','temp office C','humd parents %',
               'humd teenager 2 %','temp livroom C','humd outside %'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                 feature         VIF
# 0                lights    1.240154
# 1           humd kitc %  300.428374
# 2           humd bath %   70.100339
# 3  temp outside North C   50.249827
# 4           humd iron %  196.839580
# 5     temp teenager 2 C   88.077201
# 6        temp outside C   66.150734
# 7        wind speed m/s    4.661829
# 8            Visibility   11.315351
# 9       temp dewpoint C    8.110691

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','temp office C','humd parents %',
               'humd teenager 2 %','temp livroom C','humd outside %','humd kitc %'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                 feature        VIF
# 0                lights   1.224118
# 1           humd bath %  67.816708
# 2  temp outside North C  49.293162
# 3           humd iron %  88.611254
# 4     temp teenager 2 C  64.106380
# 5        temp outside C  65.544437
# 6        wind speed m/s   4.583458
# 7            Visibility  11.243994
# 8       temp dewpoint C   8.073163

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','temp office C','humd parents %',
               'humd teenager 2 %','temp livroom C','humd outside %','humd kitc %','humd iron %'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                 feature        VIF
# 0                lights   1.221232
# 1           humd bath %  43.513317
# 2  temp outside North C  49.256943
# 3     temp teenager 2 C  52.806463
# 4        temp outside C  64.638486
# 5        wind speed m/s   4.158919
# 6            Visibility  11.060031
# 7       temp dewpoint C   5.622752

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','temp office C','humd parents %',
               'humd teenager 2 %','temp livroom C','humd outside %','humd kitc %','humd iron %','temp outside C'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                 feature        VIF
# 0                lights   1.221050
# 1           humd bath %  43.363663
# 2  temp outside North C   8.640323
# 3     temp teenager 2 C  51.399246
# 4        wind speed m/s   4.063242
# 5            Visibility  11.029308
# 6       temp dewpoint C   4.760691

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','temp office C','humd parents %',
               'humd teenager 2 %','temp livroom C','humd outside %','humd kitc %','humd iron %','temp outside C','temp teenager 2 C'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                 feature        VIF
# 0                lights   1.220777
# 1           humd bath %  13.065728
# 2  temp outside North C   6.842040
# 3        wind speed m/s   3.965227
# 4            Visibility   9.723382
# 5       temp dewpoint C   4.558966

# %%
x = data.drop(['date','Appliances','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','temp office C','humd parents %',
               'humd teenager 2 %','temp livroom C','humd outside %','humd kitc %','humd iron %','temp outside C','temp teenager 2 C'], axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data
# Out:
#                 feature        VIF
# 0                lights   1.220777
# 1           humd bath %  13.065728
# 2  temp outside North C   6.842040
# 3        wind speed m/s   3.965227
# 4            Visibility   9.723382
# 5       temp dewpoint C   4.558966

# %% [markdown]
# # Grid Search

# %%
x = data.drop(['Appliances','date','humd outside North %','temp kitc C','temp parents C','pressure mm Hg','humd livroom','rv1',
               'rv2','humd laundary %','humd office %','temp iron C','temp laundary C','temp bath C','temp office C','humd parents %',
               'humd teenager 2 %','temp livroom C','humd outside %','humd kitc %','humd iron %','temp outside C','temp teenager 2 C'], axis=1)

# %%
y = data['Appliances']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= .3, random_state= 52)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# %%
model = SVR()
param_grid = {
    'kernel': ['linear', 'poly', 'rbf']
}

# %%
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(x_train, y_train)
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("Best Parameters:", best_params)
print("Best Cross-validation mse:", grid_search.best_score_)
print("mse", mse)

# %%
# Example using Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(random_state=42)
param_grid = {
     'n_estimators': [100, 200, 300],
     'max_depth': [None, 10, 20],
     'min_samples_split': [2, 5, 10]
}

# %%
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(x_train, y_train)
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("Best Parameters:", best_params)
print("Best Cross-validation accuracy:", grid_search.best_score_)
print("mse", mse)

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", mape)

# %% [markdown]
# # **ANN_Regressor**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
wine = pd.read_csv('Appliances Energy Prediction.csv',sep=',')
wine
# Out:
#                    date  Appliances  lights         T1       RH_1         T2  \
# 0      11-01-2016 17:00          60      30  19.890000  47.596667  19.200000
# 1      11-01-2016 17:10          60      30  19.890000  46.693333  19.200000
# 2      11-01-2016 17:20          50      30  19.890000  46.300000  19.200000
# 3      11-01-2016 17:30          50      40  19.890000  46.066667  19.200000
# 4      11-01-2016 17:40          60      40  19.890000  46.333333  19.200000
# ...                 ...         ...     ...        ...        ...        ...
# 19730  27-05-2016 17:20         100       0  25.566667  46.560000  25.890000
# 19731  27-05-2016 17:30          90       0  25.500000  46.500000  25.754000
# 19732  27-05-2016 17:40         270      10  25.500000  46.596667  25.628571
# 19733  27-05-2016 17:50         420      10  25.500000  46.990000  25.414000
# 19734  27-05-2016 18:00         430      10  25.500000  46.600000  25.264286
#
# ...

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
x = wine.drop(['Appliances', 'date'], axis=1)
y = wine['Appliances']
x
# Out:
#        lights         T1       RH_1         T2       RH_2         T3  \
# 0          30  19.890000  47.596667  19.200000  44.790000  19.790000
# 1          30  19.890000  46.693333  19.200000  44.722500  19.790000
# 2          30  19.890000  46.300000  19.200000  44.626667  19.790000
# 3          40  19.890000  46.066667  19.200000  44.590000  19.790000
# 4          40  19.890000  46.333333  19.200000  44.530000  19.790000
# ...       ...        ...        ...        ...        ...        ...
# 19730       0  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731       0  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732      10  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733      10  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734      10  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
y
# Out:
# 0         60
# 1         60
# 2         50
# 3         50
# 4         60
#         ...
# 19730    100
# 19731     90
# 19732    270
# 19733    420
# 19734    430
# Name: Appliances, Length: 19735, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train1, x_test1, y_train1, y_test1 = train_test_split(x, y, test_size=0.40, random_state=42)
x_train2, x_test2, y_train2, y_test2 = train_test_split(x, y, test_size=0.30, random_state=42)
x_train3, x_test3, y_train3, y_test3 = train_test_split(x, y, test_size=0.25, random_state=42)
x_train4 ,x_test4, y_train4, y_test4 = train_test_split(x, y, test_size=0.20, random_state=42)

# %% [markdown]
# 60-40

# %%
from sklearn.model_selection import train_test_split
x_train1, x_test1, y_train1, y_test1= train_test_split(x, y, test_size=0.40, random_state=52)

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model= tf.keras.Sequential([
                            tf.keras.layers.Dense(10),
                            tf.keras.layers.Dense(5),
                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model   # optimizer can be SGD, Adam

model.compile(loss= tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.Adam(),  #SGD
              metrics= ["mae"])

# STEP3: Fit the model

history= model.fit(x_train1, y_train1, epochs= 100, verbose=1)
# Out:
# Epoch 1/100
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 53.0392 - mae: 53.0392
# Epoch 2/100
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 49.8172 - mae: 49.8172
# Epoch 3/100
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.8209 - mae: 48.8209
# Epoch 4/100
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 48.4053 - mae: 48.4053
# Epoch 5/100
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.2473 - mae: 48.2473
# Epoch 6/100
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.0707 - mae: 48.0707
# Epoch 7/100
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 48.0517 - mae: 48.0517
# Epoch 8/100
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.9579 - mae: 47.9579
# Epoch 9/100
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47.9111 - mae: 47.9111
# Epoch 10/100
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.8409 - mae: 47.8409
# Epoch 11/100
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.8103 - mae: 47.8103
# Epoch 12/100
# ...

# %%
model.evaluate(x_test1, y_test1)
# Out:
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 44.3266 - mae: 44.3266
# [44.188209533691406, 44.188209533691406]

# %%
model.summary();
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,025 (4.01 KB)
#  Trainable params: 341 (1.33 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 684 (2.68 KB)

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model3= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(5, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model3.compile(
    loss=tf.keras.losses.MeanAbsoluteError(),
    optimizer=tf.keras.optimizers.SGD(),
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(name="mae"),
        tf.keras.metrics.MeanSquaredError(name="mse"),
        tf.keras.metrics.MeanAbsolutePercentageError(name="mape")
    ]
)


# STEP1: Fit the model

history= model3.fit(x_train1, y_train1, epochs= 250, verbose=1)
# Out:
# Epoch 1/250
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 431.7116 - mae: 431.7116 - mape: 591.9081 - mse: 7636388.5000
# Epoch 2/250
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 94.7384 - mae: 94.7384 - mape: 92.6148 - mse: 20329.0898
# Epoch 3/250
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 91.0283 - mae: 91.0283 - mape: 86.6906 - mse: 19639.8848
# Epoch 4/250
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 87.3228 - mae: 87.3228 - mape: 80.7912 - mse: 18978.6191
# Epoch 5/250
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 83.6208 - mae: 83.6208 - mape: 74.9215 - mse: 18344.9727
# Epoch 6/250
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 79.9301 - mae: 79.9301 - mape: 69.0889 - mse: 17739.6758
# Epoch 7/250
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 76.4327 - mae: 76.4327 - mape: 63.8865 - mse: 17176.7754
# Epoch 8/250
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 72.9843 - mae: 72.9843 - mape: 58.8410 - mse: 16643.6621
# Epoch 9/250
# ...

# %%
model3.evaluate(x_test1, y_test1)
# Out:
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 49.0398 - mae: 49.0398 - mape: 37.6610 - mse: 11179.9902
# [49.01476287841797, 49.01476287841797, 11192.64453125, 37.355690002441406]

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(5, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train1, y_train1, epochs= 500)
# Out:
# Epoch 1/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 123.0192 - mae: 123.0192
# Epoch 2/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 98.8908 - mae: 98.8908
# Epoch 3/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 98.5198 - mae: 98.5198
# Epoch 4/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 98.1488 - mae: 98.1488
# Epoch 5/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 97.7778 - mae: 97.7778
# Epoch 6/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 97.4068 - mae: 97.4068
# Epoch 7/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 97.0358 - mae: 97.0358
# Epoch 8/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 96.6648 - mae: 96.6648
# Epoch 9/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 96.2939 - mae: 96.2939
# Epoch 10/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 95.9229 - mae: 95.9229
# Epoch 11/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 95.5519 - mae: 95.5519
# Epoch 12/500
# ...

# %%
model2.evaluate(x_test1, y_test1)
# Out:
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 49.0383 - mae: 49.0383
# [49.01337432861328, 49.01337432861328]

# %%
model2.summary();
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 10)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,025 (4.01 KB)
#  Trainable params: 341 (1.33 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 684 (2.68 KB)

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 70-30

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(5, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train2, y_train2, epochs= 100)
# Out:
# Epoch 1/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 51.7417 - mae: 51.7417
# Epoch 2/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 49.9819 - mae: 49.9819
# Epoch 3/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 49.0940 - mae: 49.0940
# Epoch 4/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.4068 - mae: 48.4068
# Epoch 5/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.9506 - mae: 47.9506
# Epoch 6/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.7138 - mae: 47.7138
# Epoch 7/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.5904 - mae: 47.5904
# Epoch 8/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.5346 - mae: 47.5346
# Epoch 9/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.4593 - mae: 47.4593
# Epoch 10/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47.4100 - mae: 47.4100
# Epoch 11/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.3588 - mae: 47.3588
# Epoch 12/100
# ...

# %%
model2.evaluate(x_test2, y_test2)
# Out:
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 42.5624 - mae: 42.5624
# [44.988094329833984, 44.988094329833984]

# %%
model2.summary();
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 10)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,025 (4.01 KB)
#  Trainable params: 341 (1.33 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 684 (2.68 KB)

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(5, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train2, y_train2, epochs= 250)
# Out:
# Epoch 1/250
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 116.7209 - mae: 116.7209
# Epoch 2/250
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 49.4415 - mae: 49.4415
# Epoch 3/250
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 48.3744 - mae: 48.3744
# Epoch 4/250
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.8771 - mae: 47.8771
# Epoch 5/250
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.6351 - mae: 47.6351
# Epoch 6/250
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47.4743 - mae: 47.4743
# Epoch 7/250
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.3749 - mae: 47.3749
# Epoch 8/250
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.3001 - mae: 47.3001
# Epoch 9/250
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 47.2280 - mae: 47.2280
# Epoch 10/250
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.1830 - mae: 47.1830
# Epoch 11/250
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.1417 - mae: 47.1417
# Epoch 12/250
# ...

# %%
model2.evaluate(x_test2, y_test2)
# Out:
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 41.3984 - mae: 41.3984
# [43.92060089111328, 43.92060089111328]

# %%
model2.summary();
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 10)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,025 (4.01 KB)
#  Trainable params: 341 (1.33 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 684 (2.68 KB)

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(5, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train2, y_train2, epochs= 500)
# Out:
# Epoch 1/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 58.0832 - mae: 58.0832
# Epoch 2/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.6078 - mae: 48.6078
# Epoch 3/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47.6364 - mae: 47.6364
# Epoch 4/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.3766 - mae: 47.3766
# Epoch 5/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47.2774 - mae: 47.2774
# Epoch 6/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.2053 - mae: 47.2053
# Epoch 7/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.1418 - mae: 47.1418
# Epoch 8/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47.0922 - mae: 47.0922
# Epoch 9/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.0351 - mae: 47.0351
# Epoch 10/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 46.9958 - mae: 46.9958
# Epoch 11/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 46.9703 - mae: 46.9703
# Epoch 12/500
# ...

# %%
model2.evaluate(x_test2, y_test2)
# Out:
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 40.3993 - mae: 40.3993
# [42.8327522277832, 42.8327522277832]

# %%
model2.summary();
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 10)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,025 (4.01 KB)
#  Trainable params: 341 (1.33 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 684 (2.68 KB)

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 80-20

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(5, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train4, y_train4, epochs= 100)
# Out:
# Epoch 1/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 55.4248 - mae: 55.4248
# Epoch 2/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 46.0606 - mae: 46.0606
# Epoch 3/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 45.2862 - mae: 45.2862
# Epoch 4/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.9473 - mae: 44.9473
# Epoch 5/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.6913 - mae: 44.6913
# Epoch 6/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.5630 - mae: 44.5630
# Epoch 7/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.4887 - mae: 44.4887
# Epoch 8/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.3937 - mae: 44.3937
# Epoch 9/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.3449 - mae: 44.3449
# Epoch 10/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.2806 - mae: 44.2806
# Epoch 11/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.2430 - mae: 44.2430
# Epoch 12/100
# ...

# %%
model2.evaluate(x_test4, y_test4)
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 40.9013 - mae: 40.9013
# [43.278072357177734, 43.278072357177734]

# %%
model2.summary();
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 10)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,025 (4.01 KB)
#  Trainable params: 341 (1.33 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 684 (2.68 KB)

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(5, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train4, y_train4, epochs= 250)
# Out:
# Epoch 1/250
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 122.0128 - mae: 122.0128
# Epoch 2/250
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 95.5235 - mae: 95.5235
# Epoch 3/250
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 95.0263 - mae: 95.0263
# Epoch 4/250
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 94.5318 - mae: 94.5318
# Epoch 5/250
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 94.0378 - mae: 94.0378
# Epoch 6/250
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 93.5438 - mae: 93.5438
# Epoch 7/250
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 93.0498 - mae: 93.0498
# Epoch 8/250
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 92.5558 - mae: 92.5558
# Epoch 9/250
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 92.0619 - mae: 92.0619
# Epoch 10/250
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 91.5679 - mae: 91.5679
# Epoch 11/250
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 91.0739 - mae: 91.0739
# Epoch 12/250
# ...

# %%
model2.evaluate(x_test4, y_test4)
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 46.9140 - mae: 46.9140
# [49.0701904296875, 49.0701904296875]

# %%
model2.summary();
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                │ (None, 10)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,025 (4.01 KB)
#  Trainable params: 341 (1.33 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 684 (2.68 KB)

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(5, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train4, y_train4, epochs= 500)
# Out:
# Epoch 1/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.6331 - mae: 48.6331
# Epoch 2/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 46.5654 - mae: 46.5654
# Epoch 3/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 45.8364 - mae: 45.8364
# Epoch 4/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 45.4381 - mae: 45.4381
# Epoch 5/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 45.2150 - mae: 45.2150
# Epoch 6/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 45.0832 - mae: 45.0832
# Epoch 7/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.9914 - mae: 44.9914
# Epoch 8/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.9143 - mae: 44.9143
# Epoch 9/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.8576 - mae: 44.8576
# Epoch 10/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.8040 - mae: 44.8040
# Epoch 11/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.7597 - mae: 44.7597
# Epoch 12/500
# ...

# %%
model2.evaluate(x_test4, y_test4)
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 39.1019 - mae: 39.1019
# [41.492313385009766, 41.492313385009766]

# %%
model2.summary();
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                │ (None, 10)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,025 (4.01 KB)
#  Trainable params: 341 (1.33 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 684 (2.68 KB)

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 80:20

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(30, activation='relu'),
                            tf.keras.layers.Dense(20, activation='relu'),
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train4, y_train4, epochs= 500)
# Out:
# Epoch 1/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.2888 - mae: 48.2888
# Epoch 2/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 45.7181 - mae: 45.7181
# Epoch 3/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 45.3209 - mae: 45.3209
# Epoch 4/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 45.2122 - mae: 45.2122
# Epoch 5/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 45.0790 - mae: 45.0790
# Epoch 6/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44.9873 - mae: 44.9873
# Epoch 7/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.9684 - mae: 44.9684
# Epoch 8/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.8474 - mae: 44.8474
# Epoch 9/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.7723 - mae: 44.7723
# Epoch 10/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.7270 - mae: 44.7270
# Epoch 11/500
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 44.6253 - mae: 44.6253
# Epoch 12/500
# ...

# %%
model2.evaluate(x_test4, y_test4)
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 40.2537 - mae: 40.2537
# [42.621131896972656, 42.621131896972656]

# %%
model2.summary();
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_27 (Dense)                │ (None, 30)             │           840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 20)             │           620 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,045 (19.71 KB)
#  Trainable params: 1,681 (6.57 KB)
#  Non-trainable params: 0 (0.00 B)
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 70-30

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(30, activation='relu'),
                            tf.keras.layers.Dense(20, activation='relu'),
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train2, y_train2, epochs= 500)
# Out:
# Epoch 1/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 63.6639 - mae: 63.6639
# Epoch 2/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.9158 - mae: 48.9158
# Epoch 3/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.9300 - mae: 47.9300
# Epoch 4/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.6595 - mae: 47.6595
# Epoch 5/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.4878 - mae: 47.4878
# Epoch 6/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.3990 - mae: 47.3990
# Epoch 7/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.3206 - mae: 47.3206
# Epoch 8/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.2847 - mae: 47.2847
# Epoch 9/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 47.1986 - mae: 47.1986
# Epoch 10/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.1457 - mae: 47.1457
# Epoch 11/500
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.0872 - mae: 47.0872
# Epoch 12/500
# ...

# %%
model2.evaluate(x_test2, y_test2)
# Out:
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 39.0269 - mae: 39.0269
# [41.19550323486328, 41.19550323486328]

# %%
model2.summary();
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_31 (Dense)                │ (None, 30)             │           840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 20)             │           620 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,045 (19.71 KB)
#  Trainable params: 1,681 (6.57 KB)
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 75-25

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(30, activation='relu'),
                            tf.keras.layers.Dense(20, activation='relu'),
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train3, y_train3, epochs= 500)
# Out:
# Epoch 1/500
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 57.8589 - mae: 57.8589
# Epoch 2/500
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.6850 - mae: 48.6850
# Epoch 3/500
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.9476 - mae: 47.9476
# Epoch 4/500
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.5898 - mae: 47.5898
# Epoch 5/500
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.4494 - mae: 47.4494
# Epoch 6/500
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.3642 - mae: 47.3642
# Epoch 7/500
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.2863 - mae: 47.2863
# Epoch 8/500
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 47.2181 - mae: 47.2181
# Epoch 9/500
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.1812 - mae: 47.1812
# Epoch 10/500
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.0981 - mae: 47.0981
# Epoch 11/500
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.0328 - mae: 47.0328
# Epoch 12/500
# ...

# %%
model2.evaluate(x_test3, y_test3)
# Out:
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 38.9087 - mae: 38.9087
# [41.01300811767578, 41.01300811767578]

# %%
model2.summary();
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_35 (Dense)                │ (None, 30)             │           840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 20)             │           620 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,045 (19.71 KB)
#  Trainable params: 1,681 (6.57 KB)
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 60-40

# %%
tf.random.set_seed(52)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(30, activation='relu'),
                            tf.keras.layers.Dense(20, activation='relu'),
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train1, y_train1, epochs= 500)
# Out:
# Epoch 1/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 53.9951 - mae: 53.9951
# Epoch 2/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.8329 - mae: 48.8329
# Epoch 3/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.3683 - mae: 48.3683
# Epoch 4/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 48.2879 - mae: 48.2879
# Epoch 5/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.0897 - mae: 48.0897
# Epoch 6/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.9465 - mae: 47.9465
# Epoch 7/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47.8972 - mae: 47.8972
# Epoch 8/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.7998 - mae: 47.7998
# Epoch 9/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47.7321 - mae: 47.7321
# Epoch 10/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 47.6167 - mae: 47.6167
# Epoch 11/500
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47.4700 - mae: 47.4700
# Epoch 12/500
# ...

# %%
model2.evaluate(x_test1, y_test1)
# Out:
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 40.4313 - mae: 40.4313
# [40.75328826904297, 40.75328826904297]

# %%
model2.summary();
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_39 (Dense)                │ (None, 30)             │           840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 20)             │           620 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,045 (19.71 KB)
#  Trainable params: 1,681 (6.57 KB)
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
import pandas as pd
wine = pd.read_csv('Appliances Energy Prediction.csv')
